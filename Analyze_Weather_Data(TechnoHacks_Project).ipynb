# %% [markdown]
# Import modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import calendar
import datetime

# %%
df = pd.read_csv("/content/weather dataset.csv",parse_dates=True, index_col='Date/Time')
df.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# 2012-01-01 01:00:00                   Fog
# 2012-01-01 02:00:00  Freezing Drizzle,Fog
# 2012-01-01 03:00:00  Freezing Drizzle,Fog
# 2012-01-01 04:00:00                   Fog

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8784 entries, 2012-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Temp (C)            8784 non-null   float64
#  1   Dew Point Temp (C)  8784 non-null   float64
#  2   Rel Hum (%)         8784 non-null   int64
#  3   Wind Spd (km/h)     8784 non-null   int64
#  4   Visibility (km)     8784 non-null   float64
#  5   Stn Press (kPa)     8784 non-null   float64
#  6   Weather             8784 non-null   object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 549.0+ KB

# %%
df.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# 2012-01-01 01:00:00                   Fog
# 2012-01-01 02:00:00  Freezing Drizzle,Fog
# 2012-01-01 03:00:00  Freezing Drizzle,Fog
# 2012-01-01 04:00:00                   Fog

# %% [markdown]
# Find different weather conditions available

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
#        'Drizzle,Ice Pellets,Fog', 'Drizzle,Snow', 'Rain,Ice Pellets',
#        'Drizzle,Snow,Fog', 'Rain,Snow Grains', 'Rain,Snow,Ice Pellets',
#        'Snow Showers,Fog', 'Moderate Snow,Blowing Snow'], dtype=object)

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# Freezing Drizzle                              7
# Snow,Ice Pellets                              6
# Freezing Drizzle,Fog                          6
# Snow,Haze                                     5
# Freezing Fog                                  4
# Snow Showers,Fog                              4
# Moderate Snow                                 4
# Rain,Snow,Ice Pellets                         4
# Freezing Rain,Fog                             4
# Freezing Drizzle,Haze                         3
# Rain,Haze                                     3
# Thunderstorms,Rain                            3
# Thunderstorms,Rain Showers,Fog                3
# Freezing Rain,Haze                            2
# Drizzle,Snow                                  2
# Rain Showers,Snow Showers                     2
# Thunderstorms                                 2
# Moderate Snow,Blowing Snow                    2
# Rain Showers,Fog                              1
# Thunderstorms,Moderate Rain Showers,Fog       1
# Snow Pellets                                  1
# Rain,Snow,Fog                                 1
# Moderate Rain,Fog                             1
# Freezing Rain,Ice Pellets,Fog                 1
# Drizzle,Ice Pellets,Fog                       1
# Thunderstorms,Rain,Fog                        1
# Rain,Ice Pellets                              1
# Rain,Snow Grains                              1
# Thunderstorms,Heavy Rain Showers              1
# Freezing Rain,Snow Grains                     1
# Name: Weather, dtype: int64

# %% [markdown]
# Find the number of times when weather was clear.

# %%
len(df[(df.Weather=='Clear')])
          # OR,
#df[(df.Weather=='Clear')].count()[1] #OR, [0]
# Out:
# 1326

# %%
df['Wind Spd (km/h)'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
df['Wind Spd (km/h)'].value_counts()
              # OR,
            # Finest way
#df['Wind Spd (km/h)'].value_counts()[11]
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: Wind Spd (km/h), dtype: int64

# %%
df['Wind Spd (km/h)'].value_counts()[11]
#len(df[(df['Wind Spd (km/h)']==11)])
# Out:
# 677

# %%
df[(df['Wind Spd (km/h)']==11)].count()  # OR, [1]
# Out:
# Temp (C)              677
# Dew Point Temp (C)    677
# Rel Hum (%)           677
# Wind Spd (km/h)       677
# Visibility (km)       677
# Stn Press (kPa)       677
# Weather               677
# Month                 677
# dtype: int64

# %%
df[['Weather','Temp (C)']].head()
# Out:
#                                   Weather  Temp (C)
# Date/Time
# 2012-01-01 00:00:00                   Fog      -1.8
# 2012-01-01 01:00:00                   Fog      -1.8
# 2012-01-01 02:00:00  Freezing Drizzle,Fog      -1.8
# 2012-01-01 03:00:00  Freezing Drizzle,Fog      -1.5
# 2012-01-01 04:00:00                   Fog      -1.5

# %% [markdown]
# Get first 20 rows from dataset

# %%
df[:20]
  # OR,
#df[0:20]
#df.head(20)
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# 2012-01-01 05:00:00      -1.4                -3.3           87
# 2012-01-01 06:00:00      -1.5                -3.1           89
# 2012-01-01 07:00:00      -1.4                -3.6           85
# 2012-01-01 08:00:00      -1.4                -3.6           85
# 2012-01-01 09:00:00      -1.3                -3.1           88
# 2012-01-01 10:00:00      -1.0                -2.3           91
# 2012-01-01 11:00:00      -0.5                -2.1           89
# 2012-01-01 12:00:00      -0.2                -2.0           88
# 2012-01-01 13:00:00       0.2                -1.7           87
# 2012-01-01 14:00:00       0.8                -1.1           87
# 2012-01-01 15:00:00       1.8                -0.4           85
# 2012-01-01 16:00:00       2.6                -0.2           82
# 2012-01-01 17:00:00       3.0                 0.0           81
# 2012-01-01 18:00:00       3.8                 1.0           82
# 2012-01-01 19:00:00       3.1                 1.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
# 2012-01-01 05:00:00                9              6.4           101.27
# 2012-01-01 06:00:00                7              6.4           101.29
# 2012-01-01 07:00:00                7              8.0           101.26
# 2012-01-01 08:00:00                9              8.0           101.23
# 2012-01-01 09:00:00               15              4.0           101.20
# 2012-01-01 10:00:00                9              1.2           101.15
# 2012-01-01 11:00:00                7              4.0           100.98
# 2012-01-01 12:00:00                9              4.8           100.79
# 2012-01-01 13:00:00               13              4.8           100.58
# 2012-01-01 14:00:00               20              4.8           100.31
# 2012-01-01 15:00:00               22              6.4           100.07
# 2012-01-01 16:00:00               13             12.9            99.93
# 2012-01-01 17:00:00               13             16.1            99.81
# 2012-01-01 18:00:00               15             12.9            99.74
# 2012-01-01 19:00:00               15             12.9            99.68
#
#                                   Weather    Month
# Date/Time
# 2012-01-01 00:00:00                   Fog  January
# 2012-01-01 01:00:00                   Fog  January
# 2012-01-01 02:00:00  Freezing Drizzle,Fog  January
# 2012-01-01 03:00:00  Freezing Drizzle,Fog  January
# 2012-01-01 04:00:00                   Fog  January
# 2012-01-01 05:00:00                   Fog  January
# 2012-01-01 06:00:00                   Fog  January
# 2012-01-01 07:00:00                   Fog  January
# 2012-01-01 08:00:00                   Fog  January
# 2012-01-01 09:00:00                   Fog  January
# 2012-01-01 10:00:00                   Fog  January
# 2012-01-01 11:00:00                   Fog  January
# 2012-01-01 12:00:00                   Fog  January
# 2012-01-01 13:00:00                   Fog  January
# 2012-01-01 14:00:00                   Fog  January
# 2012-01-01 15:00:00                   Fog  January
# 2012-01-01 16:00:00         Mostly Cloudy  January
# 2012-01-01 17:00:00                Cloudy  January
# 2012-01-01 18:00:00                  Rain  January
# 2012-01-01 19:00:00                  Rain  January

# %% [markdown]
# First five pressure values recorded on june 6

# %%
df.loc['2012-01-06', 'Stn Press (kPa)'][:5]
# Out:
# Date/Time
# 2012-01-06 00:00:00    100.81
# 2012-01-06 01:00:00    100.81
# 2012-01-06 02:00:00    100.84
# 2012-01-06 03:00:00    100.76
# 2012-01-06 04:00:00    100.70
# Name: Stn Press (kPa), dtype: float64

# %% [markdown]
# All instance when wind speed was above 30 and visibility was 25

# %%
df[(df['Wind Spd (km/h)'] > 30) & (df['Visibility (km)']==25)]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-02 00:00:00       5.2                 1.5           77
# 2012-01-02 01:00:00       4.6                 0.0           72
# 2012-01-02 02:00:00       3.9                -0.9           71
# 2012-01-02 03:00:00       3.7                -1.5           69
# 2012-01-02 04:00:00       2.9                -2.3           69
# ...                       ...                 ...          ...
# 2012-12-16 07:00:00      -9.8               -14.9           66
# 2012-12-21 18:00:00       1.4                 0.3           92
# 2012-12-23 01:00:00      -7.9               -11.8           74
# 2012-12-26 19:00:00      -9.6               -13.1           76
# 2012-12-26 22:00:00      -9.7               -12.8           78
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-02 00:00:00               35             25.0            99.26
# 2012-01-02 01:00:00               39             25.0            99.26
# 2012-01-02 02:00:00               32             25.0            99.26
# 2012-01-02 03:00:00               33             25.0            99.30
# 2012-01-02 04:00:00               32             25.0            99.26
# ...                              ...              ...              ...
# 2012-12-16 07:00:00               32             25.0           101.89
# 2012-12-21 18:00:00               46             25.0            97.56
# 2012-12-23 01:00:00               32             25.0           100.27
# 2012-12-26 19:00:00               39             25.0           102.03
# 2012-12-26 22:00:00               37             25.0           101.70
#
#                            Weather     Month
# Date/Time
# 2012-01-02 00:00:00   Rain Showers   January
# 2012-01-02 01:00:00         Cloudy   January
# 2012-01-02 02:00:00  Mostly Cloudy   January
# 2012-01-02 03:00:00  Mostly Cloudy   January
# 2012-01-02 04:00:00  Mostly Cloudy   January
# ...                            ...       ...
# 2012-12-16 07:00:00         Cloudy  December
# 2012-12-21 18:00:00           Rain  December
# 2012-12-23 01:00:00   Snow Showers  December
# 2012-12-26 19:00:00         Cloudy  December
# 2012-12-26 22:00:00         Cloudy  December
#
# [127 rows x 8 columns]

# %% [markdown]
# Top 10 hottest temp. values

# %%
df['Temp (C)'].value_counts().sort_values(ascending=False).head(10)
                              # OR,
#new_df = df['Temp (C)'].value_counts().sort_values(ascending=False)
#new_df.iloc[:10]
# Out:
# 16.6    65
# 1.1     58
# 0.8     47
# 1.5     45
# 19.3    44
# 21.1    43
# 2.6     43
# 0.4     41
# 1.3     40
# 14.6    39
# Name: Temp (C), dtype: int64

# %% [markdown]
# Temp. recorded by month

# %%
mean_temperatures = {}

for month in range(1, 13):
  mean_temperatures[month] = df.loc[df.index.month == month, 'Temp (C)'].mean()
pd.Series(mean_temperatures)
# Out:
# 1     -7.371505
# 2     -4.225000
# 3      3.121237
# 4      7.009306
# 5     16.237769
# 6     20.134028
# 7     22.790054
# 8     22.279301
# 9     16.484444
# 10    10.954973
# 11     0.931389
# 12    -3.306317
# dtype: float64

# %% [markdown]
# Using pivot element

# %%
mean_temperature_df = df.pivot_table(values='Temp (C)', index=df.index.month, aggfunc=np.mean)
mean_temperature_df
# Out:
#             Temp (C)
# Date/Time
# 1          -7.371505
# 2          -4.225000
# 3           3.121237
# 4           7.009306
# 5          16.237769
# 6          20.134028
# 7          22.790054
# 8          22.279301
# 9          16.484444
# 10         10.954973
# 11          0.931389
# 12         -3.306317

# %% [markdown]
# Using group by

# %%
mean_temperature_df = df.groupby(df.index.month).agg(np.mean).reset_index()
mean_temperature_df['Temp (C)']
# Out:
# <ipython-input-57-752b29d8810f>:1: FutureWarning: The operation <function mean at 0x7aab48f2c160> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   mean_temperature_df = df.groupby(df.index.month).agg(np.mean).reset_index()
# 0     -7.371505
# 1     -4.225000
# 2      3.121237
# 3      7.009306
# 4     16.237769
# 5     20.134028
# 6     22.790054
# 7     22.279301
# 8     16.484444
# 9     10.954973
# 10     0.931389
# 11    -3.306317
# Name: Temp (C), dtype: float64

# %% [markdown]
# Extract month name from the date & store a new column as month

# %%
df['Month'] = df.index.month
df['Month'] = df['Month'].apply(lambda x: calendar.month_name[x])
df.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather    Month
# Date/Time
# 2012-01-01 00:00:00                   Fog  January
# 2012-01-01 01:00:00                   Fog  January
# 2012-01-01 02:00:00  Freezing Drizzle,Fog  January
# 2012-01-01 03:00:00  Freezing Drizzle,Fog  January
# 2012-01-01 04:00:00                   Fog  January

# %% [markdown]
# Get the list of month in which it rained with thunderstorm

# %%
def checkList(x):
  WeatherList = ['rain, thunderstorm']
  count = 0
  for substring in WeatherList:
    if substring in x:
      count+=1;
  if(count==2):
    return True
  else:
    return False
print("2) Get the list of months in which it rained with thunderstorm\n")
rained = df['Weather'].str.lower().apply(checkList)
month_list = df[rained]['Month'].unique()
print(month_list)
# Out:
# 2) Get the list of months in which it rained with thunderstorm
#
# []
